# %% [markdown]
# <a href="https://colab.research.google.com/github/TiagoFSS/Projetos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade 0
import matplotlib.pyplot
carga = [0.20, 0.30, 0.31, 0.50, 0.51, 1.01, 1.01, 1.00, 2.00, 2.01, 2.00, 3.01]
taxa = [2.15, 6.80, 21.86, 49.09, 85.45, 115.97, 105.06, 92.07 , 151.81, 141.94, 132.59, 142.46]
matplotlib.pyplot.plot(carga, taxa,"o")
matplotlib.pyplot.xlabel('Taxa')
matplotlib.pyplot.ylabel('Carga(g)')
matplotlib.pyplot.title('CxV')
# A relação entre a carga e a tava de disparo apresenta uma função logarítimica com um crescimento não tão rápido.
#1)
# Out:
# Text(0.5, 1.0, 'CxV')

# %%
from numpy import genfromtxt

endereço = 'https://raw.githubusercontent.com/borismarin/sample-data/master/neuro-comp/i_V_pyr1.dat'
misterio = genfromtxt(endereço)
matplotlib.pyplot.plot(misterio[:1])
# desafio: o que está contido na array `misterio`?
# Out:
# ...
#  ...]
